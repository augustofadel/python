# %% [markdown]
# Importe a biblioteca `Pandas`.

# %%
import pandas as pd

# %% [markdown]
# # California Housing

# %% [markdown]
# Importe o dataset [California Housing](https://developers.google.com/machine-learning/crash-course/california-housing-data-description) para um dataframe Pandas (ver notebook anterior: 02-análise).
#
# 💡 Cada linhas desse arquivo representa as características de uma quadra de imóveis residenciais.

# %%
df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# Quantas linhas e colunas existem no dataframe?
#
# 💡 Esta informação fica armazenada em um **atributo** do dataframe.

# %%
df.shape
# Out:
# (17000, 9)

# %% [markdown]
# Liste o nome de todas as colunas presentes no dataframe.
#
# 💡 Esta informação fica armazenada em um **atributo** do dataframe.

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# Calcule a população total da região. `population`

# %%
df['population'].sum()
# Out:
# 24302757.0

# %%
sum(df['population'])
# Out:
# 24302757.0

# %% [markdown]
# Calcule a população média por quadra. `population`

# %%
df['population'].mean()
# Out:
# 1429.5739411764705

# %% [markdown]
# Calcule o número total de domicílios na região. `households`

# %%
df['households'].sum()
# Out:
# 8520773.0

# %% [markdown]
# Encontre a maior e a menor idade mediana dos imóveis. `housing_median_age`

# %%
df['housing_median_age'].mean()
df['housing_median_age'].std()
df['housing_median_age'].min()
df['housing_median_age'].max()
# Out:
# 52.0

# %%
df['housing_median_age'].min()
# Out:
# 1.0

# %%
max(df['housing_median_age'])
# Out:
# 52.0

# %% [markdown]
# Qual é a população da quadra mais populosa? `population`

# %%
df['population'].max()
# Out:
# 35682.0

# %% [markdown]
# Identifique as coordenadas da quadra mais populosa. `longitude` e `latitude`

# %%
df.iloc[2274]
# Out:
# longitude               -117.4200
# latitude                  33.3500
# housing_median_age        14.0000
# total_rooms            25135.0000
# total_bedrooms          4819.0000
# population             35682.0000
# households              4769.0000
# median_income              2.5729
# median_house_value    134400.0000
# Name: 2274, dtype: float64

# %%
idx = df['population'].argmax()

print(df['latitude'].iloc[idx])
print(df['longitude'].iloc[idx])
# Out:
# 33.35
# -117.42

# %% [markdown]
# Identifique as coordenadas da quadra em que o valor mediano dos imóveis é mínimo. `median_house_value`

# %%
idx = df['median_house_value'].argmin()

print(df['latitude'].iloc[idx])
print(df['longitude'].iloc[idx])
# Out:
# 36.4
# -117.02

# %% [markdown]
# Calcule o número médio de moradores por domicílio.

# %%
df['population'].sum() / df['households'].sum()
# Out:
# 2.8521774961027595

# %% [markdown]
# # Múltiplos registros
#
# Quando uma base de dados armazena histórico, é comum a presença de múltiplos registros para um mesmo identificador.
#
# Embora façam referência ao mesmo indivíduo (unidade de análise), esses registros não são necessariamente duplicados e podem trazer informações em diferentes situações, como ao longo do tempo, por exemplo.

# %% [markdown]
# Identificador como índice

# %%
df = pd.DataFrame(
    data=[
        ['direito', '05/02/2021', 'não'],
        ['direito', '10/02/2021', 'não'],
        ['engenharia', '19/08/2021', 'não'],
        ['enfermagem', '13/02/2022', 'não'],
        ['administração', '01/03/2023', 'sim'],
        ['engenharia', '10/03/2023', 'sim'],
        ['psicologia', '04/09/2023', 'não']
    ],
    index=['000000001-00', '000000002-00', '000000001-00', '000000001-00', '000000002-00', '000000003-00', '000000001-00'],
    columns=['curso', 'data', 'concluido']
)

df
# Out:
#                       curso        data concluido
# 000000001-00        direito  05/02/2021       não
# 000000002-00        direito  10/02/2021       não
# 000000001-00     engenharia  19/08/2021       não
# 000000001-00     enfermagem  13/02/2022       não
# 000000002-00  administração  01/03/2023       sim
# 000000003-00     engenharia  10/03/2023       sim
# 000000001-00     psicologia  04/09/2023       não

# %% [markdown]
# Identificador como coluna

# %%
df = pd.DataFrame(
    data=[
        ['000000001-00', 'direito', '05/02/2021', 'não'],
        ['000000002-00', 'direito', '10/02/2023', 'não'],
        ['000000001-00', 'engenharia', '19/08/2021', 'não'],
        ['000000001-00', 'enfermagem', '13/02/2022', 'não'],
        ['000000002-00', 'administração', '01/03/2020', 'sim'],
        ['000000003-00', 'engenharia', '10/03/2015', 'sim'],
        ['000000001-00', 'psicologia', '04/09/2023', 'não']
    ],
    columns=['cpf', 'curso', 'data', 'concluido']
)

df
# Out:
#             cpf          curso        data concluido
# 0  000000001-00        direito  05/02/2021       não
# 1  000000002-00        direito  10/02/2023       não
# 2  000000001-00     engenharia  19/08/2021       não
# 3  000000001-00     enfermagem  13/02/2022       não
# 4  000000002-00  administração  01/03/2020       sim
# 5  000000003-00     engenharia  10/03/2015       sim
# 6  000000001-00     psicologia  04/09/2023       não

# %%
df.sort_values(by='cpf')
# Out:
#             cpf          curso        data concluido
# 0  000000001-00        direito  05/02/2021       não
# 2  000000001-00     engenharia  19/08/2021       não
# 3  000000001-00     enfermagem  13/02/2022       não
# 6  000000001-00     psicologia  04/09/2023       não
# 1  000000002-00        direito  10/02/2023       não
# 4  000000002-00  administração  01/03/2020       sim
# 5  000000003-00     engenharia  10/03/2015       sim

# %%
df.sort_values(by='data').drop_duplicates(subset='cpf', keep='last')
# Out:
#             cpf       curso        data concluido
# 1  000000002-00     direito  10/02/2023       não
# 5  000000003-00  engenharia  10/03/2015       sim
# 2  000000001-00  engenharia  19/08/2021       não

# %%
df['data'] = pd.to_datetime(df['data'], format='%d/%m/%Y')
df.sort_values(by=['cpf', 'data'])
# Out:
#             cpf          curso       data concluido
# 0  000000001-00        direito 2021-02-05       não
# 2  000000001-00     engenharia 2021-08-19       não
# 3  000000001-00     enfermagem 2022-02-13       não
# 6  000000001-00     psicologia 2023-09-04       não
# 4  000000002-00  administração 2020-03-01       sim
# 1  000000002-00        direito 2023-02-10       não
# 5  000000003-00     engenharia 2015-03-10       sim

# %%
df_dedup = df.sort_values(by='data').drop_duplicates(subset='cpf', keep='last')
df_dedup
# Out:
#             cpf       curso       data concluido
# 5  000000003-00  engenharia 2015-03-10       sim
# 1  000000002-00     direito 2023-02-10       não
# 6  000000001-00  psicologia 2023-09-04       não

# %%
df_dedup.sort_values(by='cpf')
# Out:
#             cpf       curso       data concluido
# 6  000000001-00  psicologia 2023-09-04       não
# 1  000000002-00     direito 2023-02-10       não
# 5  000000003-00  engenharia 2015-03-10       sim

# %%
df_dedup[df_dedup['concluido'] == 'não']
# Out:
#             cpf       curso       data concluido
# 1  000000002-00     direito 2023-02-10       não
# 6  000000001-00  psicologia 2023-09-04       não

# %%
df_dedup[df_dedup['curso'] == 'direito']
# Out:
#             cpf    curso       data concluido
# 1  000000002-00  direito 2023-02-10       não
